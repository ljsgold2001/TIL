# %%
result =[]
n=9


def recursion():
    
    if len(result) == 3:
        print (result)
        
    else:

        for i in range(n):
            
            result.append(i)
            print("""""")
            recursion()
    

recursion()

# %%
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-15-d887aa7268d5> in <module>
# ----> 1 recursion(4)
#
# <ipython-input-13-644605cb4f05> in recursion(k)
#      13             result.append(i)
#      14             print("""""")
# ---> 15             recursion(k+1)
#      16
#      17
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-13-644605cb4f05> in recursion(k)
#      13             result.append(i)
#      14             print("""""")
# ---> 15             recursion(k+1)
#      16
#      17
#
# RecursionError: maximum recursion depth exceeded while calling a Python object
