# %%
def getResult(x):
    aeioucount = 0
    remaincount =0
    if x == n:
        for i in result:
            print("@@")
            print("i:",i)
            if i in aeiou:
                aeioucount +=1
                print("###")
                print("i:",i)   
                
            else:
                remaincount +=1
        print(aeioucount, remaincount)
        if aeioucount <1 and remaincount<2:
            
            return
        else:
            for i in range(len(result)-1):
                
                if (ord(result[i]) > ord(result[i+1])):
                    return
        print(result)
        
    else:
        for i in range(len(word)):
            if(check[i] ==0):
                result[x] =word[i]
                check[i] =1
                getResult(x+1)
                check[i] =0

# %%
n ,list_num = map(int, input().split())
result = [0]*n
check= [0]* 1000 #인덱스가 아니라 실제 값이 있는지 없는지 확인하는 배열이다.
aeiou = ['a','e','i,','o','u']

word = input().split(" ")

getResult(0)
# Out:
# 4 6
# a t c i s w
# @@
# i: a
# ###
# i: a
# @@
# i: t
# @@
# i: c
# @@
# i: i
# 1 3
# @@
# i: a
# ###
# i: a
# @@
# i: t
# @@
# i: c
# @@
# i: s
# 1 3
# @@
# i: a
# ###
# i: a
# @@
# i: t
# @@
# i: c
# @@
# i: w
# 1 3
# @@
# i: a
# ###
# i: a
# @@
# i: t
# @@
# i: i
# @@
# i: c
# 1 3
# @@
# i: a
# ###
# i: a
# @@
# i: t
# @@
# i: i
# @@
# i: s
# 1 3
# @@
# i: a
# ###
# i: a
# @@
# i: t
# @@
# i: i
# @@
# i: w
# 1 3
# @@
# i: a
# ###
# i: a
# @@
# i: t
# @@
# i: s
# @@
# i: c
# 1 3
# @@
# i: a
# ###
# i: a
# @@
# i: t
# @@
# i: s
# @@
# i: i
# 1 3
# @@
# i: a
# ###
# i: a
# @@
# i: t
# @@
# i: s
# @@
# i: w
# 1 3
# @@
# i: a
# ###
# i: a
# @@
# i: t
# @@
# i: w
# @@
# i: c
# 1 3
# @@
# i: a
# ###
# i: a
# @@
# i: t
# @@
# i: w
# @@
# i: i
# 1 3
# @@
# i: a
# ###
# i: a
# @@
# i: t
# @@
# i: w
# @@
# i: s
# 1 3
# @@
# i: a
# ###
# i: a
# @@
# i: c
# @@
# i: t
# @@
# i: i
# 1 3
# @@
# i: a
# ###
# i: a
# @@
# i: c
# @@
# i: t
# @@
# i: s
# 1 3
# @@
# i: a
# ###
# i: a
# @@
# i: c
# @@
# ...

# %% [markdown]
# ####

# %%
# Out:
# str
